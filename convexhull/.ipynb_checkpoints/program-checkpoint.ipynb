# %% [markdown]
# # Projekt

# %% [markdown]
# ### Spis treści
# <a id="spis"></a>
#
# 1. [Generator zbiorow](#generator)
# 2. [Wybor zbiorow](#ustalenieZbiorow)
# 3. [Wizualizacja dla algorytmu Jarvisa](#jarvis)
#
#     - [Jarvis dla zbioru typu a](#jarvisa)
#     - [Jarvis dla zbioru typu b](#jarvisb)
#     - [Jarvis dla zbioru typu c](#jarvisc)
#     - [Jarvis dla zbioru typu d](#jarvisd)
#
# 4. [Wizualizacja dla algorytmu Grahama](#graham)
#
#     - [Graham dla zbioru typu a](#grahama)
#     - [Graham dla zbioru typu b](#grahamb)
#     - [Graham dla zbioru typu c](#grahamc)
#     - [Graham dla zbioru typu d](#grahamd)
#
# 5. [Wizualizacja dla algorytmu Gorna-dolna](#goradol)
#
#     - [Gorna-dolna dla zbioru typu a](#goradola)
#     - [Gorna-dolna dla zbioru typu b](#goradolb)
#     - [Gorna-dolna dla zbioru typu c](#goradolc)
#     - [Gorna-dolna dla zbioru typu d](#goradold)
#
# 6. [Wizualizacja dla algorytmu Przyrostowego](#przyrost)
#
#     - [Przyrostowy dla zbioru typu a](#przyrosta)
#     - [Przyrostowy dla zbioru typu b](#przyrostb)
#     - [Przyrostowy dla zbioru typu c](#przyrostc)
#     - [Przyrostowy dla zbioru typu d](#przyrostd)
#
# 7. [Wizualizacja dla algorytmu Dziel i zwyciezaj](#dziel)
#     - [Dziel i zwyciezaj dla zbioru typu a](#dziela)
#     - [Dziel i zwyciezaj dla zbioru typu b](#dzielb)
#     - [Dziel i zwyciezaj dla zbioru typu c](#dzielc)
#     - [Dziel i zwyciezaj dla zbioru typu d](#dzield)
#
# 8. [Wizualizacja dla algorytmu Chana](#chan)
#     - [Chan dla zbioru typu a](#chana)
#     - [Chan dla zbioru typu b](#chanb)
#     - [Chan dla zbioru typu c](#chanc)
#     - [Chan dla zbioru typu d](#chand)
#
# 9. [Wizualizacja dla algorytmu Quick hull](#quickhull)
#     - [Quick hull dla zbioru typu a](#quickhulla)
#     - [Quick hull dla zbioru typu b](#quickhullb)
#     - [Quick hull dla zbioru typu c](#quickhullc)
#     - [Quick hull dla zbioru typu d](#quickhulld)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Importy
# <a id="konfiguracja"></a>

# %% [markdown]
# <a id='section_id'></a>

# %%
from lib import *
import numpy as np
from vis.divide_conq_vis import divide_conq_vis
from vis.graham_vis import *
from vis.increase_vis import *
from vis.divide_conq_vis import *
from vis.jarvis_vis import *
from vis.lowerupper_vis import *
from vis.chan_vis import *
from vis.quickhull_vis import *
# Funkcje wizualizujące Łukasza

# wypisywanie otoczek w czytelnej formie
from pprint import pprint
from copy import deepcopy

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Utilities

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Genertor zbiorów punktów
#
# <a id="generator"></a>
# [spis treści](#spis)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %%
import random 
import math
def makeAset(n,x1=-100,y1=100,x2=-100,y2=100):
    return [(random.randint(x1,y1), random.randint(x2,y2)) for i in range(n)]

def makeBset(n,xs=0,ys=0,r=100):
    b = []
    for _ in range(n):
        t = random.random() * (2*math.pi)
        b.append((r*math.sin(t)-xs, r*math.cos(t)-ys))
    return b
        
def makeCset(n,x1=-100,y1=-100,x2=100,y2=-100,x3=100,y3=100,x4=-100,y4=100): # wierzcholki musza byc podawane 
# kolejno w przeciwnym kierunku do ruchu wskazowek 
# zegara makeCset tworzy wszelakie czworokaty, bioirac pod uwage ze prostokaty moglyby byc przechylone wyznaczanie zbiorow
# punktow dla nich bylo by rownie trudne
    C=[]
    a=np.sqrt((x1-x2)**2+(y1-y2)**2)
    b=np.sqrt((x2-x3)**2+(y2-y3)**2)
    c=np.sqrt((x3-x4)**2+(y3-y4)**2)
    d=np.sqrt((x1-x4)**2+(y1-y4)**2)
    obw=a+b+c+d
    s=random.random()*obw

    for _ in range(n):
        s =random.random() * obw
        if s<=a:
            C.append(((x1+(s/a)*(x2-x1),y1+(y2-y1)*(s/a))))
        elif s<=a+b:
            C.append((x2+(x3-x2)*((s-a)/b),y2+(y3-y2)*((s-a)/b)))
        elif s<=a+b+c:
            C.append((x3+(x4-x3)*((s-a-b)/c),y3+(y4-y3)*((s-b-a)/c)))
        else:
            C.append((x4+(x1-x4)*((s-a-b-c)/d),y4+(y1-y4)*((s-b-a-c)/d)))
    return C

def makeDset(x1=0,y1=0,x2=10,y2=0,x3=10,y3=10,x4=0,y4=10,n1=100,n2=100,n=0):
    if(n!=0):
        n1=n
        n2=n
    D=[]
    D.append((x1,y1))
    D.append((x2,y2))
    D.append((x3,y3))
    D.append((x4,y4))
    a=np.sqrt((x2-x1)**2+(y2-y1)**2)
    d=np.sqrt((x3-x1)**2+(y3-y1)**2)
    
    for _ in range(n1):
        s=random.random()*a
        D.append((x1+(x2-x1)*(s/a),y1+(y2-y1)*(s/a)))
        D.append((x4+(x1-x4)*(s/a),y4+(y1-y4)*(s/a)))
    for _ in range(n2):
        s=random.random()*d
        D.append((x1+(x3-x1)*(s/d),y1+(y3-y1)*(s/d)))
        D.append((x2+(x4-x2)*(s/d),y2+(y4-y2)*(s/d)))
    return D

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Wybor zbiorow
#
# <a id="ustalenieZbiorow"></a>
# [spis treści](#spis)

# %%
a=makeAset(n=400)
b=makeBset(n=400)
c=makeCset(n=400)
d=makeDset(n=400)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Sekcja Wizualizacji
#
# <a id="wizualizacja"></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm Jarvisa
#
# <a id="jarvis"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla chmury punktów
#
# <a id="jarvisa"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot=jarvis_vis(np.array(a))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 14
# Punkty otoczki:
# array([[ -52, -100],
#        [  32, -100],
#        [  81,  -96],
#        [  99,  -76],
#        [  96,   98],
#        [  29,   99],
#        [  -7,   98],
#        [ -95,   95],
#        [ -99,   59],
#        [-100,   34],
#        [-100,   21],
#        [ -99,  -64],
#        [ -96,  -82],
#        [ -71,  -93]])
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="jarvisb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = jarvis_vis(np.array(b))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
#        [-73.80090525, -67.47908108],
#        [-73.56894744, -67.73189774],
#        [-73.31557826, -68.00607314],
#        [-72.78911463, -68.56927003],
#        [-71.48248634, -69.93035212],
#        [-68.91909453, -72.45797685],
#        [-66.99314695, -74.24229429],
#        [-66.8671494 , -74.35579554],
#        [-66.43037421, -74.74627337],
#        [-64.92709487, -76.05571873],
#        [-64.37307465, -76.5252067 ],
#        [-64.2218971 , -76.65212282],
#        [-63.55826005, -77.20328736],
#        [-62.59964958, -77.98258698],
#        [-62.33762582, -78.1922017 ],
#        [-61.42805321, -78.90877187],
#        [-61.35419461, -78.96621305],
#        [-61.17186067, -79.10754365],
#        [-61.04055032, -79.20890869],
#        [-59.86901207, -80.09807359],
#        [-58.67525487, -80.97662913],
#        [-56.85298589, -82.2662628 ],
#        [-55.6532899 , -83.08255728],
#        [-55.62830385, -83.09928887],
#        [-55.05683759, -83.47900715],
#        [-54.58959212, -83.78529962],
#        [-53.28891796, -84.61850402],
#        [-52.85539124, -84.8899736 ],
#        [-52.79300306, -84.92878681],
#        [-52.62768737, -85.03132671],
#        [-50.07142125, -86.56126601],
#        [-45.98809996, -88.79805551],
#        [-42.63660192, -90.4550727 ],
#        [-41.67264226, -90.90319514],
#        [-41.30176521, -91.07230199],
#        [-39.57219535, -91.83703694],
#        [-36.96528886, -92.91699209],
#        [-36.22366274, -93.20861686],
#        [-36.14254738, -93.24010011],
#        [-33.79359846, -94.11690976],
#        [-32.9416437 , -94.41847335],
#        [-32.70798913, -94.49966903],
#        [-29.29840038, -95.6117343 ],
#        [-27.69185145, -96.08934053],
#        [-26.84900345, -96.32824619],
#        [-26.03126671, -96.55243732],
#        [-24.11985828, -97.04757821],
#        [-23.05654894, -97.30568098],
#        [-21.37250422, -97.68938562],
#        [-20.88505753, -97.79475636],
#        [-18.41125   , -98.29051772],
#        [-17.86131151, -98.39193845],
#        [-16.68633313, -98.59800346],
#        [-15.76065248, -98.75019916],
#        [-15.52709749, -98.7871917 ],
#        [-15.48752789, -98.79340302],
#        [-14.20997966, -98.98523364],
#        [-14.19988306, -98.98668254],
#        [-13.48980952, -99.08594774],
#        [-12.49685223, -99.2160707 ],
#        [-12.06321461, -99.26972778],
#        [-11.97386802, -99.28054434],
#        [-10.30132425, -99.46799847],
#        [-10.07980031, -99.49069115],
#        [ -9.93008894, -99.50574523],
#        [ -6.12386926, -99.812315  ],
#        [ -4.08420402, -99.91656158],
#        [ -3.68867821, -99.93194511],
#        [ -3.54707437, -99.93707152],
#        [ -1.337625  , -99.9910534 ]])
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="jarvisc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook 

ch, plot = jarvis_vis(np.array(c))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)


plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# array([[ -98.7563896 , -100.        ],
#        [  96.79367409, -100.        ],
#        [ 100.        ,  -99.52610531],
#        [ 100.        ,   99.3762691 ],
#        [  99.28706561,  100.        ],
#        [ -99.96929176,  100.        ],
#        [-100.        ,   97.11149087],
#        [-100.        ,  -98.84467852]])
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="jarvisd"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %%
# %matplotlib notebook

ch, plot = jarvis_vis(np.array(d))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)


plot.draw()
# Out:
# Liczba punktow otoczki: 4
# Punkty otoczki:
# array([[ 0.,  0.],
#        [10.,  0.],
#        [10., 10.],
#        [ 0., 10.]])
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm Grahama
#
# <a id="graham"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Graham - wizualizacja dla chmury punktów
#
# <a id="grahama"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#graham)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

# przekazujemy kopię listy punktów, ponieważ algorytm sortujący modyfikuje listę w miejscu
ch, plot = graham_vis(a.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 14
# Punkty otoczki:
# [(-52, -100),
#  (32, -100),
#  (81, -96),
#  (99, -76),
#  (96, 98),
#  (29, 99),
#  (-7, 98),
#  (-95, 95),
#  (-99, 59),
#  (-100, 34),
#  (-100, 21),
#  (-99, -64),
#  (-96, -82),
#  (-71, -93)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Graham - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="grahamb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#graham)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

# przekazujemy kopię listy punktów, poinieważ algorytm sortujący modyfikuje listę w miejscu
ch, plot = graham_vis(b.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)


plot.draw()
# Out:
# Liczba punktow otoczki: 400
# Punkty otoczki:
# [(-0.4726227103631404, -99.99888313263128),
#  (3.597211099016415, -99.93527941777674),
#  (5.48610740031098, -99.84939972574824),
#  (6.388516280560892, -99.79572565863234),
#  (6.751040006189863, -99.77185704814171),
#  (7.919933025385588, -99.68587994732958),
#  (7.969626573387853, -99.6819193850156),
#  (10.421306288640904, -99.45549947206706),
#  (11.034260349235012, -99.38936109335495),
#  (11.153456121586373, -99.37605554933164),
#  (13.03864955158601, -99.14632427816437),
#  (16.719903703143064, -98.59231623284657),
#  (16.802061334709734, -98.57834820539779),
#  (18.947683306714723, -98.18851917260207),
#  (19.23386599359236, -98.13286095360988),
#  (20.7019733603754, -97.83367671199068),
#  (21.656769435061598, -97.62676035614713),
#  (24.264751608434874, -97.01145205273941),
#  (27.24472832413694, -96.21707113887832),
#  (29.738835290683376, -95.47566012106753),
#  (30.127899151003895, -95.35360345968546),
#  (30.14231170266015, -95.34904847569102),
#  (31.83463873343637, -94.79744604530015),
#  (33.02821492342882, -94.38822500170131),
#  (34.93353711221527, -93.69977579924873),
#  (35.14695397728171, -93.61993177800784),
#  (38.22187695553441, -92.4071865278669),
#  (38.44813519810798, -92.31327585882764),
#  (39.75831150975491, -91.75661646929495),
#  (41.080966692416375, -91.17211292723547),
#  (42.54588099780577, -90.49777903418708),
#  (44.26651952704332, -89.66869715213828),
#  (44.89739989377973, -89.35448216389611),
#  (45.16810006885606, -89.21795075078673),
#  (46.06050343329939, -88.7605206354211),
#  (47.73671025904839, -87.87039600254266),
#  (48.594168063388096, -87.39912373832584),
#  (49.63431167053526, -86.8126436931405),
#  (49.75560671538651, -86.7431818668406),
#  (49.900791823970565, -86.65974252985495),
#  (50.072039336360405, -86.56090847893162),
#  (51.012289683022104, -86.01015231526704),
#  (54.89141920472209, -83.58787051774598),
#  (57.248910745712955, -81.99123257049739),


# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

# przekazujemy kopię listy punktów, ponieważ algorytm sortujący modyfikuje listę w miejscu
ch, plot=graham_vis(c.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# [(-98.75638959524534, -100.0),
#  (96.7936740892564, -100.0),
#  (100.0, -99.52610531114257),
#  (100.0, 99.37626910042559),
#  (99.28706560901486, 100.0),
#  (-99.96929175831906, 100.0),
#  (-100.0, 97.11149087388856),
#  (-100.0, -98.84467851727982)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Graham - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="grahamd"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#graham)

# %%
# %matplotlib notebook

# przekazujemy kopię listy punktów, ponieważ algorytm sortujący modyfikuje listę w miejscu
ch, plot = graham_vis(d.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 4
# Punkty otoczki:
# [(0, 0), (10, 0), (10, 10), (0, 10)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm gorna - dolna
#
# <a id="goradol"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Gorna-dolna - wizualizacja dla chmury punktów
#
# <a id="goradola"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#goradol)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = lower_upper_vis(a.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 14
# Punkty otoczki:
# [(-100, 21),
#  (-100, 34),
#  (-99, 59),
#  (-95, 95),
#  (-7, 98),
#  (29, 99),
#  (96, 98),
#  (99, -76),
#  (81, -96),
#  (32, -100),
#  (-52, -100),
#  (-71, -93),
#  (-96, -82),
#  (-99, -64)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Gorna-dolna - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="goradolb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#goradol)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = lower_upper_vis(b.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 396
# Punkty otoczki:
# [(-99.99988583895312, -0.1511032638452165),
#  (-99.96854238396912, 2.5080936235653555),
#  (-99.96519886121119, 2.6379948139640623),
#  (-99.94410852085393, 3.342928651911934),
#  (-99.90814124308488, 4.285243674728356),
#  (-99.56599164068398, 9.306627133782102),
#  (-98.87904430515479, 14.930994518090051),
#  (-98.61620392413248, 16.578429467048917),
#  (-97.59748290894218, 21.78833012965286),
#  (-96.87483657040401, 24.804556828484444),
#  (-96.85565169339306, 24.87936363832741),
#  (-96.69395529455427, 25.500568807278405),
#  (-96.55101456391574, 26.03654329358125),
#  (-95.9431043038758, 28.19433873201513),
#  (-95.29697460867607, 30.306544349914745),
#  (-94.35153658435279, 33.13287708864927),
#  (-94.21690292355734, 33.51380616243061),
#  (-93.78983357366872, 34.69102359722938),
#  (-93.20387207797557, 36.23586937928168),
#  (-93.13328447877973, 36.416909838626985),
#  (-92.78143057848082, 37.30423755835982),
#  (-92.51602608709437, 37.95767270331616),
#  (-92.0960421021537, 38.96561341899202),
#  (-92.06651197876626, 39.03533491676084),
#  (-90.68703392206872, 42.1409762394935),
#  (-87.3033053215296, 48.76610380106021),
#  (-86.52582918345266, 50.13263292622852),
#  (-85.64611239744863, 51.62115294337772),
#  (-84.33863737240033, 53.73075698486631),
#  (-82.48442299252399, 56.536005904117246),
#  (-81.02573438680534, 58.60742586975538),
#  (-79.75260578590076, 60.32844992504539),
#  (-79.52676655328472, 60.62584763596591),
#  (-79.36090217745931, 60.84280734466263),
#  (-78.41395401030051, 62.058454834699816),
></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#goradol)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = lower_upper_vis(c.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# [(-100.0, -98.84467851727982),
#  (-100.0, 97.11149087388856),
#  (-99.96929175831906, 100.0),
#  (99.28706560901486, 100.0),
#  (100.0, 99.37626910042559),
#  (100.0, -99.52610531114257),
#  (96.7936740892564, -100.0),
#  (-98.75638959524534, -100.0)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Gorna-dolna - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="goradold"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#goradol)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = lower_upper_vis(d.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 4
# Punkty otoczki:
# [(0, 0), (0, 10), (10, 10), (10, 0)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm przyrostowy
#
# <a id="przyrost"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla chmury punktów
#
# <a id="przyrosta"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = increase_with_sorting_vis(a.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-5049d613a1aa> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2
# ----> 3 ch, plot = increase_with_sorting_vis(a.copy())
#       4
#       5 print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/increase_vis.py in increase_with_sorting_vis(point2_set)
#     175         # znajdujemy styczne
#     176         left_tangent_idx = left_tangent(convex_hull, point2_set[i])
# --> 177         right_tangent_idx = right_tangent(convex_hull, point2_set[i])
#     178
#     179         if left_tangent_idx is None:
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/increase_vis.py in right_tangent(polygon, point)
#      68             else:
#      69                 # jeżeli v_mid > v_left
# ---> 70                 if orientation(point, polygon[mid % n], polygon[left % n]) == 1:
#      71                     right = mid
#      72
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in orientation(p1, p2, p3, eps)
#      41     eps <- tolerancja dla zera
#      42     """
# ---> 43     det = det3x3(p1[0], p1[1], 1,
#      44                  p2[0], p2[1], 1,
#      45                  p3[0], p3[1], 1)
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy- wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="przyrostb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = increase_with_sorting_vis(b.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 100
# Punkty otoczki:
# [(-99.59085208993285, 9.036712898013153),
#  (-99.54515256061052, -9.526940835587094),
#  (-99.08616187611777, -13.488236528908592),
#  (-98.58874783979752, -16.740931855211066),
#  (-97.885295644348, -20.456512327828193),
#  (-96.33973651856083, -26.80774454396112),
#  (-95.93351652206479, -28.22694471087373),
#  (-95.33294787425372, -30.19319541891557),
#  (-91.05147463717536, -41.34765974509093),
#  (-90.25525517402507, -43.057971543857235),
#  (-83.84688275513132, -54.49495620924256),
#  (-83.40606358457342, -55.167277958279726),
#  (-80.3685889851874, -59.50537710602308),
#  (-79.26334169673677, -60.96985044320142),
#  (-74.61911151599577, -66.57317925834238),
#  (-66.43927955595396, -74.73835783642693),
#  (-65.61180125981232, -75.46583025080218),
#  (-61.5441853396014, -78.81822917881874),
#  (-61.3165868297884, -78.99541872504392),
#  (-61.070418064549706, -79.1858828164536),
#  (-57.651871884876705, -81.70839411082416),
#  (-49.339346657569614, -86.98062353998259),
#  (-43.28939405937099, -90.14448603199475),
#  (-33.39207252264656, -94.26011612894561),
#  (-31.97547616580863, -94.75003389957074),
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="przyrostc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = increase_with_sorting_vis(c.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-347d05d00913> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2
# ----> 3 ch, plot = increase_with_sorting_vis(c.copy())
#       4
#       5 print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/increase_vis.py in increase_with_sorting_vis(point2_set)
#     174         # znajdujemy styczne
#     175         # znajdujemy styczne
# --> 176         left_tangent_idx = left_tangent(convex_hull, point2_set[i])
#     177         right_tangent_idx = right_tangent(convex_hull, point2_set[i])
#     178
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/increase_vis.py in left_tangent(polygon, point)
#     101
#     102         # sprawdzamy czy polygon[mid] nie jest szukanym punktem styczności
# --> 103         if (not is_mid_down) and orientation(point, polygon[(mid - 1) % n], polygon[mid % n]) == 1:
#     104             return mid % n
#     105
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in orientation(p1, p2, p3, eps)
#      40     eps <- tolerancja dla zera
#      41     """
# ---> 42     det = det3x3(p1[0], p1[1], 1,
#      43                  p2[0], p2[1], 1,
#      44                  p3[0], p3[1], 1)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in det3x3(ux, uy, uz, vx, vy, vz, wx, wy, wz)
#      30             wx, wy, wz) -> float:
#      31     """ Zwraca wyznacznik 3x3 obliczony metodą Sarussa (bez redukcji wyrazów) """
# ---> 32     return (ux * vy * wz) + (uy * vz * wx) + (uz * vx * wy) - (wx * vy * uz) - (wy * vz * ux) - (wz * vx * uy)
#      33
#      34
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="przyrostd"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

d = makeDset(n=2)
print(d)
ch, plot = increase_with_sorting_vis(d.copy())

# print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
# pprint(ch)

plot.draw()

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm dziel i zwyciezaj
#
# <a id="dziel"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj - wizualizacja dla chmury punktów
#
# <a id="dziela"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5

a = makeAset(n=400)
ch, plot = divide_conq_vis(a.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-eb7cbe1c5bed> in <module>
#       4
#       5 a = makeAset(n=400)
# ----> 6 ch, plot = divide_conq_vis(a.copy(), k)
#       7
#       8 print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_vis(point2_set, k)
#     358
#     359
# --> 360     convex_hull = divide_conq_rec_viz(point2_set, scenes)
#     361
#     362     scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     310         ))
#     311
# --> 312         right_convex_hull = divide_conq_rec_viz(right_points, scenes)
#     313
#     314         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     293
#     294
# --> 295         left_convex_hull = divide_conq_rec_viz(left_points, scenes)
#     296
#     297         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     310         ))
#     311
# --> 312         right_convex_hull = divide_conq_rec_viz(right_points, scenes)
#     313
#     314         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     310         ))
#     311
# --> 312         right_convex_hull = divide_conq_rec_viz(right_points, scenes)
#     313
#     314         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     293
#     294
# --> 295         left_convex_hull = divide_conq_rec_viz(left_points, scenes)
#     296
#     297         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     310         ))
#     311
# --> 312         right_convex_hull = divide_conq_rec_viz(right_points, scenes)
#     313
#     314         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     310         ))
#     311
# --> 312         right_convex_hull = divide_conq_rec_viz(right_points, scenes)
#     313
#     314         scenes.append(Scene(
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/divide_conq_vis.py in divide_conq_rec_viz(points, scenes)
#     259             return points
#     260         elif len(points) <= k:
# --> 261             convex_hull = jarvis(np.array(points))
#     262             scenes.append(Scene(
#     263                 points=[
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/jarvis.py in jarvis(points)
#      34         for i in range(len(points)):
#      35             if i != prev and i != imax:
# ---> 36                 orient = orientation(points[prev], points[imax], points[i], EPS)
#      37                 # jeżeli punkt jest po prawej stronie rozważanego wektora,
#      38                 #to jest nowym kandydatem na punkt otoczki
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="dzielb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5
ch, plot = divide_conq_vis(b.copy(), k)

print(f'Liczba punktow  otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow  otoczki: 399
# Punkty otoczki:
# [array([ 2.10412568, 99.97786082]),
#  array([-1.22690539, 99.99247323]),
#  array([-2.56561895, 99.96708258]),
#  array([-3.9121343 , 99.92344672]),
#  array([-6.20317972, 99.80741737]),
#  array([-8.56992874, 99.63210487]),
#  array([-8.93800707, 99.59975918]),
#  array([-9.72277396, 99.52621598]),
#  array([-11.82839648,  99.29798103]),
#  array([-12.47710073,  99.21855652]),
#  array([-12.89557494,  99.1650349 ]),
#  array([-14.70818249,  98.91243283]),
#  array([-18.77008778,  98.22262369]),
#  array([-18.95866411,  98.18639954]),
#  array([-19.07941738,  98.16300644]),
#  array([-20.55166981,  97.86536092]),
#  array([-22.20564763,  97.50338052]),
#  array([-26.24999882,  96.49319956]),
#  array([-26.50491754,  96.4234896 ]),
#  array([-26.867115  ,  96.32319623]),
#  array([-27.93335331,  96.01941352]),
#  array([-31.5096081 ,  94.90597767]),
#  array([-31.53765364,  94.89666171]),
#  array([-33.4439633 ,  94.24171751]),
#  array([-36.59634503,  93.06292242]),
#  array([-38.34790818,  92.35495622]),
#  array([-39.48248908,  91.87563908]),
#  array([-42.53584513,  90.50249653]),
#  array([-44.24790502,  89.67788413]),
#  array([-45.50012401,  89.04908037]),
#  array([-50.56575405,  86.2734288 ]),
#  array([-52.14185533,  85.3301056 ]),
#  array([-53.7560509,  84.3225177]),
#  array([-56.23096014,  82.69267877]),
#  array([-58.60816244,  81.02520161]),
#  array([-59.9773675 ,  80.01696938]),
#  array([-60.44512958,  79.66420972]),
#  array([-63.22570975,  77.4758648 ]),
#  array([ 87.64147712, -48.15570047]),
#  array([ 88.58931754, -46.3889299 ]),
#  array([ 90.13288283, -43.31354791]),
#  array([ 90.2609785 , -43.04597264]),
#  array([ 91.62892628, -40.05171494]),
#  array([ 92.07942591, -39.00486283]),
#  array([ 92.8820217 , -37.05307065]),
#  array([ 92.90277272, -37.00101108]),
#  array([ 93.01253932, -36.72420903]),
#  array([ 93.41680475, -35.68333771]),
#  array([ 95.13662507, -30.80620992]),
#  array([ 95.6169009 , -29.28153448]),
#  array([ 96.10625184, -27.63310255]),
#  array([ 96.1685367 , -27.41555304]),
#  array([ 96.49297034, -26.25084143]),
#  array([ 97.01505031, -24.25036108]),
#  array([ 97.54885304, -22.00502829]),
#  array([ 97.58277596, -21.85410341]),
#  array([ 98.27812345, -18.47729556]),
#  array([ 98.40204734, -17.80553505]),
#  array([ 98.63023942, -16.49472256]),
#  array([ 99.16566015, -12.89076596]),
#  array([ 99.46553817, -10.32505285]),
#  array([99.59098075, -9.03529486]),
#  array([99.59480866, -8.99300212]),
#  array([99.72541922, -7.40545488]),
#  array([99.79928752, -6.33263067]),
#  array([99.90792174, -4.29035822]),
#  array([99.93071759, -3.72178484]),
#  array([99.96317038, -2.71377354]),
#  array([99.99751507, -0.70496768]),
#  array([99.99461402,  1.03786646]),
#  array([99.96965676,  2.46327577]),
#  array([99.94777131,  3.23156481]),
#  array([99.76100255,  6.90958537]),
#  array([99.47941471, 10.19048815]),
#  array([99.2287005 , 12.39616868]),
#  array([98.93176307, 14.57759434]),
#  array([98.92239644, 14.64102052]),
#  array([98.42731263, 17.6653369 ]),
#  array([98.27810196, 18.47740989]),
#  array([98.0774495 , 19.51445359]),
#  array([98.06229527, 19.59046317]),
#  array([97.94294683, 20.17868097]),
#  array([97.80564346, 20.83401323]),
#  array([97.74178266, 21.13158588]),
#  array([97.61282831, 21.71947859]),
#  array([97.54203137, 22.03524712]),
#  array([97.03729876, 24.16118063]),
#  array([96.6688477 , 25.59558329]),
#  array([96.37313306, 26.6874357 ]),
#  array([96.33493443, 26.82499596]),
#  array([95.96218393, 28.12933089]),
#  array([95.12454734, 30.8434838 ]),
#  array([95.12291299, 30.84852385]),
#  array([94.91922895, 31.46966755]),
#  array([94.54875773, 32.5658166 ]),
#  array([94.12841834, 33.76152929]),
#  array([93.91502032, 34.35067624]),
#  array([93.65782896, 35.04584246]),
#  array([93.49157345, 35.48697921]),
#  array([92.81499018, 37.22066089]),
#  array([92.65360014, 37.62061111]),
#  array([91.99897832, 39.19423411]),
#  array([91.77865809, 39.70740383]),
#  array([90.63944489, 42.24323651]),
#  array([88.65183488, 46.26934377]),
#  array([88.34597725, 46.85070227]),
#  array([87.91100793, 47.66187874]),
#  array([86.69206686, 49.84461398]),
#  array([85.78953309, 51.38244849]),
#  array([84.94818685, 52.76178116]),
#  array([83.56912438, 54.91995495]),
#  array([83.46676328, 55.07539766]),
#  array([82.28160939, 56.83077297]),
#  array([81.57808705, 57.83611081]),
#  array([81.53112163, 57.9022988 ]),
#  array([80.84966952, 58.8500717 ]),
#  array([80.8121437 , 58.90159106]),
#  array([78.85664066, 61.49496096]),
#  array([78.06816569, 62.49289164]),
#  array([77.70701782, 62.94139641]),
#  array([76.52093761, 64.3781493 ]),
#  array([75.42844559, 65.65477588]),
#  array([74.06562073, 67.18842033]),
#  array([73.97680058, 67.28620197]),
#  array([73.13799388, 68.1970223 ]),
#  array([71.46953236, 69.94359116]),
#  array([70.20591081, 71.2118676 ]),
#  array([68.83331786, 72.53946755]),
#  array([67.39430926, 73.87832618]),
#  array([66.62250492, 74.57507518]),
#  array([66.17059448, 74.97634578]),
#  array([63.610313  , 77.16040488]),
#  array([63.58672854, 77.17984163]),
#  array([63.39782655, 77.3350864 ]),
#  array([63.13658737, 77.54850956]),
#  array([61.90883092, 78.53213771]),
#  array([60.83797655, 79.36460552]),
#  array([58.09476697, 81.394091  ]),
#  array([57.95085112, 81.49661867]),
#  array([57.24939112, 81.99089716]),
#  array([56.73538955, 82.34740781]),
#  array([54.84810698, 83.61629722]),
#  array([53.1766587 , 84.68909593]),
#  array([52.47463222, 85.12586548]),
#  array([51.02080262, 86.00510275]),
#  array([48.02751662, 87.71178739]),
#  array([47.94605095, 87.75634563]),
#  array([44.56988435, 89.5182965 ]),
#  array([43.52127254, 90.03276535]),
#  array([40.62665875, 91.3754595 ]),
#  array([40.43084204, 91.46227098]),
#  array([32.63214621, 94.52588552]),
#  array([31.68300612, 94.84823205]),
#  array([28.83964001, 95.75111051]),
#  array([28.40848823, 95.87991342]),
#  array([19.61239949, 98.05791037]),
#  array([19.34367337, 98.11127509]),
#  array([17.98437069, 98.36951973]),
#  array([17.34437896, 98.48437703]),
#  array([16.4858101 , 98.63172951]),
#  array([15.59408129, 98.7766401 ]),
#  array([14.07593756, 99.00438365]),
#  array([13.86285063, 99.03444538]),
#  array([12.43344478, 99.22403666]),
#  array([11.99918691, 99.27748745]),
#  array([11.91364006, 99.28778969]),
#  array([11.45598996, 99.34163424]),
#  array([10.795485  , 99.41557978]),
#  array([ 9.01292784, 99.59300744]),
#  array([ 8.86057414, 99.60667762]),
#  array([ 6.08570435, 99.81464924]),
#  array([ 2.83750999, 99.95973458]),
#  array([ 2.63196904, 99.96535769])]
# <img src="data:," width="0">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj  - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="dzielc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5

ch, plot = divide_conq_vis(c.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
# pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj  - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="dzield"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5
ch, plot = divide_conq_vis(d.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 4
# Punkty otoczki:
# [array([ 0., 10.]), array([0., 0.]), array([10.,  0.]), array([10., 10.])]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm chana
#
# <a id="chan"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan - wizualizacja dla chmury punktów
#
# <a id="chana"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
a = makeAset(n=100)
plot=chan_vis(a,visual=True)
plot.draw()
# Out:
# <img src="data:," width="0">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan  - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="chanb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=chan_vis(b,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan   - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="chanc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

plot=chan_vis(c,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan   - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="chand"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=chan_vis(d,visual=True)
plot.draw()
# Out:
# tangent_l UTIL zwraca NONE
# (9.89204578275619, 0.10795421724380971)
# [(0.9853990929371437, 0.0),
#  (10, 0),
#  (5.374278893576005, 5.374278893576005),
#  (2.425145042365445, 7.574854957634555),
#  (0.0, 6.511912852760384),
#  (0.0, 4.284424024517305),
#  (0.08692801607750877, 0.08692801607750877)]
# (5.374278893576005, 5.374278893576005) (10, 0)
# tangent_l UTIL zwraca NONE
# (9.89204578275619, 0.10795421724380971)
# [(2.25982532384719, 0.0),
#  (7.074981755749449, 0.0),
#  (9.91307198392249, 0.08692801607750877),
#  (10, 10),
#  (0.0, 9.014600907062857),
#  (0.0, 2.0856608037727886)]
# (10, 10) (9.91307198392249, 0.08692801607750877)
# tangent_l UTIL zwraca NONE
# (9.89204578275619, 0.10795421724380971)
# [(5.022520610274733, 0.0),
#  (9.003356802945678, 0.0),
#  (9.950405002847688, 0.049594997152311304),
#  (6.841599271938209, 6.841599271938209),
#  (0.5394417599971817, 9.460558240002818),
#  (0.0, 2.7666496643786376),
#  (0.0, 0.7571043760503784),
#  (0.14431848888546983, 0.14431848888546983)]
# (6.841599271938209, 6.841599271938209) (9.950405002847688, 0.049594997152311304)
# tangent_l UTIL zwraca NONE
# (9.89204578275619, 0.10795421724380971)
# [(4.450863576407177, 0.0),
#  (9.73691560720043, 0.0),
#  (9.988810547704302, 0.0111894522956979),
#  (6.72186186246673, 6.72186186246673),
#  (0.0, 7.988271766362958),
#  (0.0, 1.2926928529626238)]
# (6.72186186246673, 6.72186186246673) (9.988810547704302, 0.0111894522956979)
# tangent_l UTIL zwraca NONE
# (9.89204578275619, 0.10795421724380971)
# [(8.563013553160275, 0.0),
#  (9.983833045824213, 0.0),
#  (9.73966370848159, 9.73966370848159),
#  (0.635278405608565, 9.364721594391435),
#  (0.0, 5.988695934149955),
#  (0.0, 0.27803550923468023)]
# (8.563013553160275, 0.0) (0.0, 0.27803550923468023)
# tangent_l UTIL zwraca NONE
# (9.945900017894925, 9.945900017894925)
# [(2.25982532384719, 0.0),
#  (7.074981755749449, 0.0),
#  (9.91307198392249, 0.08692801607750877),
#  (10, 10),
#  (0.0, 9.014600907062857),
#  (0.0, 2.0856608037727886)]
# (0.0, 9.014600907062857) (10, 10)
# <img src="data:image/png;base64,..." width="940">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm QuickHull
#
# <a id="quickhull"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull - wizualizacja dla chmury punktów
#
# <a id="quickhulla"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

a = makeAset(n = 1000)
plot=quickHull_vis(a,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="quickhullb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull_vis(b,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull  - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="quickhullc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull_vis(c,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull  - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="quickhulld"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull_vis(d,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Sekcja pomiarów czasu
#
# <a id="pomiary"></a>

# %% [markdown]
# ### Funkcja do pomiaru czasów i wizualizacji wyników

# %% [markdown]
# <a id='section_id'></a>

# %%
import time


from pure.graham import *
from pure.jarvis import *
from pure.divide_conq import *
from pure.chan import *
from pure.increase import *
from pure.lowerupper import *
from pure.quickhull import *

from lib.timemeasure import *

def generate_plot(xdatas, ydatas, xlabel, ylabel, title):
    for xdata, ydata in zip(xdatas, ydatas):
        plt.plot(xdata, ydata, ls = '--')
        plt.scatter(xdata, ydata)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Zredefiniowane kody funkcji funkcji wyznaczających otoczkę bez wizualizacji - wizualizacja mogła by wpływać na korzyść niektórych i niekorzyść innych. Przed uruchomieniem pomiarów czasu uruchomić komórki z nowymi definicjami.
#
# <a id="jarvis"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Pomiary

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chmura punktów

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 1000 + i * 100 for i in range(10) ]

funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_a = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeAset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
#             print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_a[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_a[fi][i] = avg_exec_time(func, points=points.copy())
        
#         print(exectimes_a[fi][i])
        
    

    
pprint(exectimes_a)
# Out:
# array([[0.02217391, 0.02369129, 0.02586174, 0.02721882, 0.03073379,
#         0.03558827, 0.03824864, 0.03830565, 0.03987212, 0.04518166],
#        [0.00594594, 0.00576926, 0.00645173, 0.00681375, 0.00867802,
#         0.00807567, 0.00871861, 0.00909635, 0.00962541, 0.01015413],
#        [0.09548744, 0.16964461, 0.183632  , 0.12310384, 0.14351571,
#         0.22199572, 0.24601157, 0.25741115, 0.27522344, 0.28790383],
#        [0.00269294, 0.00292629, 0.00318667, 0.00342803, 0.00372536,
#         0.00402358, 0.00424429, 0.00457021, 0.0047943 , 0.00517982],
#        [0.1522358 , 0.09492786, 0.12382411, 0.19636462, 0.16831505,
#         0.21668749, 0.12433298, 0.17302113, 0.27577789, 0.17526456]])

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algorytm "górna-dolna"

# %%
# %matplotlib notebook


generate_plot([ns], [exectimes_a[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zbiorczy

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_a))], exectimes_a, 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull', 'Jarvis'))
plt.show()

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Rozkład kołowy

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 100 + i * 100 for i in range(10) ]
funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_b = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeBset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_b[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_b[fi][i] = avg_exec_time(func, points=points.copy())
        
    
pprint(exectimes_b)
# Out:
# <function graham at 0x7f4bd16ca040> 100
# <function lower_upper at 0x7f4bcd0a5790> 100
# <function chan at 0x7f4bcd0f5ee0> 100
# <function quickHull at 0x7f4bcd0a5af0> 100
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 100
# <function graham at 0x7f4bd16ca040> 200
# <function lower_upper at 0x7f4bcd0a5790> 200
# <function chan at 0x7f4bcd0f5ee0> 200
# <function quickHull at 0x7f4bcd0a5af0> 200
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 200
# <function graham at 0x7f4bd16ca040> 300
# <function lower_upper at 0x7f4bcd0a5790> 300
# <function chan at 0x7f4bcd0f5ee0> 300
# <function quickHull at 0x7f4bcd0a5af0> 300
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 300
# <function graham at 0x7f4bd16ca040> 400
# <function lower_upper at 0x7f4bcd0a5790> 400
# <function chan at 0x7f4bcd0f5ee0> 400
# <function quickHull at 0x7f4bcd0a5af0> 400
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 400
# <function graham at 0x7f4bd16ca040> 500
# <function lower_upper at 0x7f4bcd0a5790> 500
# <function chan at 0x7f4bcd0f5ee0> 500
# <function quickHull at 0x7f4bcd0a5af0> 500
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 500
# <function graham at 0x7f4bd16ca040> 600
# <function lower_upper at 0x7f4bcd0a5790> 600
# <function chan at 0x7f4bcd0f5ee0> 600
# <function quickHull at 0x7f4bcd0a5af0> 600
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 600
# <function graham at 0x7f4bd16ca040> 700
# <function lower_upper at 0x7f4bcd0a5790> 700
# <function chan at 0x7f4bcd0f5ee0> 700
# <function quickHull at 0x7f4bcd0a5af0> 700
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 700
# <function graham at 0x7f4bd16ca040> 800
# <function lower_upper at 0x7f4bcd0a5790> 800
# <function chan at 0x7f4bcd0f5ee0> 800
# <function quickHull at 0x7f4bcd0a5af0> 800
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 800
# <function graham at 0x7f4bd16ca040> 900
# <function lower_upper at 0x7f4bcd0a5790> 900
# <function chan at 0x7f4bcd0f5ee0> 900
# <function quickHull at 0x7f4bcd0a5af0> 900
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 900
# <function graham at 0x7f4bd16ca040> 1000
# <function lower_upper at 0x7f4bcd0a5790> 1000
# <function chan at 0x7f4bcd0f5ee0> 1000
# <function quickHull at 0x7f4bcd0a5af0> 1000
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1000
# array([[1.97991900e-03, 3.37286600e-03, 4.73906200e-03, 7.02170500e-03,
#         8.95684000e-03, 1.07546930e-02, 1.27438290e-02, 1.67188210e-02,
#         1.61685120e-02, 1.96216370e-02],
#        [5.62267000e-04, 7.88900001e-04, 1.16162700e-03, 1.53891800e-03,
#         1.96064200e-03, 2.46206600e-03, 2.74516100e-03, 3.16541500e-03,
#         3.53657500e-03, 4.22408900e-03],
#        [1.62008150e-02, 3.03421610e-02, 8.14160020e-02, 1.10717324e-01,
#         1.23778888e-01, 1.59605960e-01, 1.82077633e-01, 2.17643089e-01,
#         2.47320683e-01, 2.70550351e-01],
#        [2.89394000e-04, 6.03174001e-04, 8.08887002e-04, 1.12101800e-03,
#         1.40860200e-03, 1.63048700e-03, 1.89767300e-03, 2.21036400e-03,
#         2.57789200e-03, 2.69894700e-03],
#        [5.91233610e-02, 2.36371654e-01, 5.23691651e-01, 9.59325040e-01,
#         1.48315859e+00, 2.10853586e+00, 2.86987546e+00, 3.86695873e+00,
#         4.83595146e+00, 5.88915134e+00]])

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algortym "górna-dolna"

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-6ab352c54037> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2
# ----> 3 generate_plot([ns], [exectimes_b[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')
#       4
#       5 plt.show()
#
# NameError: name 'exectimes_b' is not defined

# %% [markdown]
# ### Algorytm Chana

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-182ba3e63ca6> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2
# ----> 3 generate_plot([ns], [exectimes_b[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')
#       4
#       5 plt.show()
#
# NameError: name 'exectimes_b' is not defined

# %% [markdown]
# ### Algorytm QuickHull

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Algorytm Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Ujęcie zbiorcze

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_b))], exectimes_b, 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull', 'Jarvis'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Ujęcie zbiorcze bez algorytmu Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_b) - 1)], exectimes_b[:len(exectimes_b)-1], 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze bez algorytmu Jarvisa')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Losowy rozkład na prostokącie

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 10 + i * 100 for i in range(10) ]
funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_c = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeCset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_c[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_c[fi][i] = avg_exec_time(func, points=points.copy())
        
    
pprint(exectimes_c)
# Out:
# <function graham at 0x7f63c48601f0> 10
# <function lower_upper at 0x7f63c4865dc0> 10
# <function chan at 0x7f63c48655e0> 10
# <function quickHull at 0x7f63c48061f0> 10
# <function jarvis at 0x7f63c4b12820> zmieniam na np.array
# <function jarvis at 0x7f63c4b12820> 10
# <function graham at 0x7f63c48601f0> 110
# <function lower_upper at 0x7f63c4865dc0> 110
# <function chan at 0x7f63c48655e0> 110
# <function quickHull at 0x7f63c48061f0> 110
# <function jarvis at 0x7f63c4b12820> zmieniam na np.array
# <function jarvis at 0x7f63c4b12820> 110
# <function graham at 0x7f63c48601f0> 210
# <function lower_upper at 0x7f63c4865dc0> 210
# <function chan at 0x7f63c48655e0> 210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-477ceb3aca3a> in <module>
#      19
#      20         print(func, n)
# ---> 21         exectimes_c[fi][i] = avg_exec_time(func, points=points.copy())
#      22
#      23
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in avg_exec_time(func, points, times, *args)
#      27     for _ in range(times):
#      28         points_copy = points.copy()
# ---> 29         total_exec_time += get_exec_time(func, *args, points = points_copy)
#      30
#      31     return total_exec_time / times
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in get_exec_time(func, points, *args)
#      14
#      15     tstart = timer()
# ---> 16     func(points, *args)
#      17     tstop = timer()
#      18     return (tstop - tstart)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in chan(points)
#      50     hoax = None
#      51     while hoax == None:
# ---> 52         hoax = chanUtil(points, m)
#      53         m = min(n, m * m)
#      54
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in chanUtil(points, m)
#      37     while i < m:
#      38         ans.append(C[curr[0]][curr[1]])
# ---> 39         if nextvert(C, curr) == (0, 0):
#      40             return ans
#      41         curr = nextvert(C, curr)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in nextvert(C, curr)
#      19     nxt = (i, (j + 1) % len(C[i]))
#      20     for k in range(len(C)):
# ---> 21         t = tangent(C[i][j], C[k])
#      22         if t != None and k != i and compr(C[nxt[0]][nxt[1]], C[k][t], C[i][j]) > 0 and (k, t) != (curr):
#      23             nxt = (k, t)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/tangent.py in tangent(p, Q, accur)
#      35             return tangetUtil(p, Q, l, mid - 1)
#      36
# ---> 37     return tangetUtil(p, Q, 0, ln - 1)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/tangent.py in tangetUtil(p, Q, l, r)
#      28                     (Q[mid][1] <= p[1] <= Q[(mid + 1) % ln][1])):
#      29
# ---> 30             while (det(p, Q[mid], Q[(mid + 1) % ln]) == 0):
#      31                 mid = (mid + 1) % ln  # jesli jest styczna wspolliniowa, to bierzmy pod uwage punkt blizszy
#      32             return mid
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/det.py in det(a, b, c)
#       1 def det(a,b,c):
# ----> 2     return a[0]*b[1]-a[0]*c[1]-b[0]*a[1]+b[0]*c[1]+c[0]*a[1]-c[0]*b[1]
#       3
#       4
#       5 def length(v):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_c[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()

# %% [markdown]
# ### Algorytm "górna-dolna"

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_c[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()

# %% [markdown]
# ### Algorytm Chana

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_c[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()

# %% [markdown]
# ### Algorytm QuickHull

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_c[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()

# %% [markdown]
# ### Algorytm Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_c[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()

# %% [markdown]
# ### Ujęcie zbiorcze

# %% [markdown]
# ### Wierzchołki kwadratu, jego przekątne i dwa boki o wspólnym wierzchołku

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 10 + i * 100 for i in range(10) ]
funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_d = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeDset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_d[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_d[fi][i] = avg_exec_time(func, points=points.copy())
        
    
pprint(exectimes_d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cfadecac1895> in <module>
#       1 #lista liczb punktów na których ma być testowany algorytm
#       2 ns = [ 10 + i * 100 for i in range(10) ]
# ----> 3 funcs = [graham, lower_upper, chan, quickHull, jarvis]
#       4
#       5 exectimes_d = np.zeros(shape=(len(funcs), len(ns)))
#
# NameError: name 'lower_upper' is not defined

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_d[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()

# %% [markdown]
# ### Algorytm "górna-dolna"

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_d[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()

# %% [markdown]
# ### Algorytm Chana

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_d[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()

# %% [markdown]
# ### Algorytm QuickHull

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_d[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()

# %% [markdown]
# ### Algorytm Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_d[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()

# %% [markdown]
# ### Ujęcie zbiorcze

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>
