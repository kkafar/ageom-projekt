# %% [markdown]
# # Projekt

# %% [markdown]
# ### Spis treści
# <a id="spis"></a>
#
# 1. [Generator zbiorow](#generator)
# 2. [Wybor zbiorow](#ustalenieZbiorow)
# 3. [Wizualizacja dla algorytmu Jarvisa](#jarvis)
#
#     - [Jarvis dla zbioru typu a](#jarvisa)
#     - [Jarvis dla zbioru typu b](#jarvisb)
#     - [Jarvis dla zbioru typu c](#jarvisc)
#     - [Jarvis dla zbioru typu d](#jarvisd)
#
# 4. [Wizualizacja dla algorytmu Grahama](#graham)
#
#     - [Graham dla zbioru typu a](#grahama)
#     - [Graham dla zbioru typu b](#grahamb)
#     - [Graham dla zbioru typu c](#grahamc)
#     - [Graham dla zbioru typu d](#grahamd)
#
# 5. [Wizualizacja dla algorytmu Gorna-dolna](#goradol)
#
#     - [Gorna-dolna dla zbioru typu a](#goradola)
#     - [Gorna-dolna dla zbioru typu b](#goradolb)
#     - [Gorna-dolna dla zbioru typu c](#goradolc)
#     - [Gorna-dolna dla zbioru typu d](#goradold)
#
# 6. [Wizualizacja dla algorytmu Przyrostowego](#przyrost)
#
#     - [Przyrostowy dla zbioru typu a](#przyrosta)
#     - [Przyrostowy dla zbioru typu b](#przyrostb)
#     - [Przyrostowy dla zbioru typu c](#przyrostc)
#     - [Przyrostowy dla zbioru typu d](#przyrostd)
#
# 7. [Wizualizacja dla algorytmu Dziel i zwyciezaj](#dziel)
#     - [Dziel i zwyciezaj dla zbioru typu a](#dziela)
#     - [Dziel i zwyciezaj dla zbioru typu b](#dzielb)
#     - [Dziel i zwyciezaj dla zbioru typu c](#dzielc)
#     - [Dziel i zwyciezaj dla zbioru typu d](#dzield)
#
# 8. [Wizualizacja dla algorytmu Chana](#chan)
#     - [Chan dla zbioru typu a](#chana)
#     - [Chan dla zbioru typu b](#chanb)
#     - [Chan dla zbioru typu c](#chanc)
#     - [Chan dla zbioru typu d](#chand)
#
# 9. [Wizualizacja dla algorytmu Quick hull](#quickhull)
#     - [Quick hull dla zbioru typu a](#quickhulla)
#     - [Quick hull dla zbioru typu b](#quickhullb)
#     - [Quick hull dla zbioru typu c](#quickhullc)
#     - [Quick hull dla zbioru typu d](#quickhulld)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Importy
# <a id="konfiguracja"></a>

# %% [markdown]
# <a id='section_id'></a>

# %%
from lib import *
import numpy as np
from vis.divide_conq_vis import divide_conq_vis
from vis.graham_vis import *
from vis.increase_vis import *
from vis.divide_conq_vis import *
from vis.jarvis_vis import *
from vis.lowerupper_vis import *
from vis.chan_vis import *
from vis.quickhull_vis import *
# Funkcje wizualizujące Łukasza

# wypisywanie otoczek w czytelnej formie
from pprint import pprint
from copy import deepcopy

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Utilities

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Genertor zbiorów punktów
#
# <a id="generator"></a>
# [spis treści](#spis)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %%
import random 
import math
def makeAset(n,x1=-100,y1=100,x2=-100,y2=100):
    return [(random.randint(x1,y1), random.randint(x2,y2)) for i in range(n)]

def makeBset(n,xs=0,ys=0,r=100):
    b = []
    for _ in range(n):
        t = random.random() * (2*math.pi)
        b.append((r*math.sin(t)-xs, r*math.cos(t)-ys))
    return b
        
def makeCset(n,x1=-100,y1=-100,x2=100,y2=-100,x3=100,y3=100,x4=-100,y4=100): # wierzcholki musza byc podawane 
# kolejno w przeciwnym kierunku do ruchu wskazowek 
# zegara makeCset tworzy wszelakie czworokaty, bioirac pod uwage ze prostokaty moglyby byc przechylone wyznaczanie zbiorow
# punktow dla nich bylo by rownie trudne
    C=[]
    a=np.sqrt((x1-x2)**2+(y1-y2)**2)
    b=np.sqrt((x2-x3)**2+(y2-y3)**2)
    c=np.sqrt((x3-x4)**2+(y3-y4)**2)
    d=np.sqrt((x1-x4)**2+(y1-y4)**2)
    obw=a+b+c+d
    s=random.random()*obw

    for _ in range(n):
        s =random.random() * obw
        if s<=a:
            C.append(((x1+(s/a)*(x2-x1),y1+(y2-y1)*(s/a))))
        elif s<=a+b:
            C.append((x2+(x3-x2)*((s-a)/b),y2+(y3-y2)*((s-a)/b)))
        elif s<=a+b+c:
            C.append((x3+(x4-x3)*((s-a-b)/c),y3+(y4-y3)*((s-b-a)/c)))
        else:
            C.append((x4+(x1-x4)*((s-a-b-c)/d),y4+(y1-y4)*((s-b-a-c)/d)))
    return C

def makeDset(x1=0,y1=0,x2=10,y2=0,x3=10,y3=10,x4=0,y4=10,n1=100,n2=100,n=0):
    if(n!=0):
        n1=n
        n2=n
    D=[]
    D.append((x1,y1))
    D.append((x2,y2))
    D.append((x3,y3))
    D.append((x4,y4))
    a=np.sqrt((x2-x1)**2+(y2-y1)**2)
    d=np.sqrt((x3-x1)**2+(y3-y1)**2)
    
    for _ in range(n1):
        s=random.random()*a
        D.append((x1+(x2-x1)*(s/a),y1+(y2-y1)*(s/a)))
        D.append((x4+(x1-x4)*(s/a),y4+(y1-y4)*(s/a)))
    for _ in range(n2):
        s=random.random()*d
        D.append((x1+(x3-x1)*(s/d),y1+(y3-y1)*(s/d)))
        D.append((x2+(x4-x2)*(s/d),y2+(y4-y2)*(s/d)))
    return D

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Wybor zbiorow
#
# <a id="ustalenieZbiorow"></a>
# [spis treści](#spis)

# %%
a=makeAset(n=30)
b=makeBset(n=100)
c=makeCset(n=100)
d=makeDset(n=100)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Sekcja Wizualizacji
#
# <a id="wizualizacja"></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm Jarvisa
#
# <a id="jarvis"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla chmury punktów
#
# <a id="jarvisa"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot=jarvis_vis(np.array(a))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# array([[  70, -100],
#        [  97,  -54],
#        [  97,   33],
#        [  94,   93],
#        [ -69,  100],
#        [ -89,   87],
#        [ -96,  -48],
#        [ -92,  -97]])
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Jarvis - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="jarvisb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#jarvis)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = jarvis_vis(np.array(b))

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 100
# Punkty otoczki:
# array([[  3.93207545, -99.92266401],
#        [  9.68782709, -99.52962376],
#        [ 21.08233394, -97.75241785],
#        [ 22.57546519, -97.41841906],
#        [ 26.82407509, -96.33519085],
#        [ 41.20952304, -91.114078  ],
#        [ 45.8264068 , -88.88160912],
#        [ 56.26216993, -82.67144752],
#        [ 62.73830258, -77.87108185],
#        [ 63.55203152, -77.20841463],
#        [ 70.22800308, -71.19008065],
#        [ 71.77031704, -69.63491647],
#        [ 77.02708608, -63.77168659],
#        [ 79.86736304, -60.17644323],
#        [ 81.88709723, -57.39776396],
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/vis/increase_vis.py in left_tangent(polygon, point)
#     101
#     102         # sprawdzamy czy polygon[mid] nie jest szukanym punktem styczności
# --> 103         if (not is_mid_down) and orientation(point, polygon[(mid - 1) % n], polygon[mid % n]) == 1:
#     104             return mid % n
#     105
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in orientation(p1, p2, p3, eps)
#      40     eps <- tolerancja dla zera
#      41     """
# ---> 42     det = det3x3(p1[0], p1[1], 1,
#      43                  p2[0], p2[1], 1,
#      44                  p3[0], p3[1], 1)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in det3x3(ux, uy, uz, vx, vy, vz, wx, wy, wz)
#      30             wx, wy, wz) -> float:
#      31     """ Zwraca wyznacznik 3x3 obliczony metodą Sarussa (bez redukcji wyrazów) """
# ---> 32     return (ux * vy * wz) + (uy * vz * wx) + (uz * vx * wy) - (wx * vy * uz) - (wy * vz * ux) - (wz * vx * uy)
#      33
#      34
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="przyrostd"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

d = makeDset(n=2)
print(d)
ch, plot = increase_with_sorting_vis(d.copy())

# print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
# pprint(ch)

plot.draw()

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm dziel i zwyciezaj
#
# <a id="dziel"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj - wizualizacja dla chmury punktów
#
# <a id="dziela"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = increase_with_sorting_vis(b.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="przyrostc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

ch, plot = increase_with_sorting_vis(c.copy())

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Przyrostowy - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="przyrostd"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#przyrost)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

d = makeDset(n=2)
print(d)
ch, plot = increase_with_sorting_vis(d.copy())

# print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
# pprint(ch)

plot.draw()
# Out:
# [(0, 0), (10, 0), (10, 10), (0, 10), (3.3930724648399915, 0.0), (0.0, 6.6069275351600085), (5.918335499909297, 0.0), (0.0, 4.081664500090703), (0.8491655308619472, 0.8491655308619472), (9.150834469138053, 0.8491655308619472), (0.9338551817302865, 0.9338551817302865), (9.066144818269713, 0.9338551817302865)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm dziel i zwyciezaj
#
# <a id="dziel"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj - wizualizacja dla chmury punktów
#
# <a id="dziela"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 3 

a = makeAset(n=1000)
ch, plot = divide_conq_vis(a.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 9
# Punkty otoczki:
# [(-100, 99),
#  array([-100,  -72]),
#  (-97, -99),
#  (-73, -100),
#  (79, -100),
#  (98, -96),
#  (99, -31),
#  (99, 93),
#  (82, 99)]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="dzielb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5
ch, plot = divide_conq_vis(b.copy(), k)

print(f'Liczba punktow  otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow  otoczki: 100
# Punkty otoczki:
# [array([-7.5619464 , 99.71367492]),
#  array([-12.79850158,  99.17761016]),
#  array([-14.30646714,  98.97133422]),
#  array([-19.52050332,  98.0762456 ]),
#  array([-21.20208662,  97.72651392]),
#  array([-26.33582308,  96.46981094]),
#  array([-33.07399362,  94.37219371]),
#  array([-35.43474057,  93.51138519]),
#  array([-42.02917528,  90.73890249]),
#  array([-44.17781542,  89.71243294]),
#  array([-46.16712517,  88.70511008]),
#  array([-46.30875445,  88.63125443]),
#  array([-53.81561607,  84.28451499]),
#  array([-65.96909264,  75.15370128]),
#  array([-75.41248277,  65.67311049]),
#  array([-78.06397168,  62.49813057]),
#  array([-82.20995862,  56.9343719 ]),
#  array([-86.40308564,  50.34388535]),
#  array([-87.67225902,  48.09963615]),
#  array([-92.20441512,  38.70847236]),
#  array([-93.07142997,  36.57470332]),

# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj  - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="dzielc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5

ch, plot = divide_conq_vis(c.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
# pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 8
# Punkty otoczki:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Dziel i zwyciezaj  - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="dzield"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#dziel)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook

k = 5
ch, plot = divide_conq_vis(d.copy(), k)

print(f'Liczba punktow otoczki: {len(ch)}\nPunkty otoczki:')
pprint(ch)

plot.draw()
# Out:
# Liczba punktow otoczki: 4
# Punkty otoczki:
# [array([ 0., 10.]), array([0., 0.]), array([10.,  0.]), array([10., 10.])]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm chana
#
# <a id="chan"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan - wizualizacja dla chmury punktów
#
# <a id="chana"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
a = makeAset(n=100)
plot=chan(a,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan  - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="chanb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=chan(b,visual=True)
plot.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1215828d51a7> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 plot=chan(b,visual=True)
#       3 plot.draw()
#
# NameError: name 'b' is not defined

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan   - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="chanc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
print(len(c))
plot=chan(c,visual=True)
plot.draw()
# Out:
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-00079be324d5> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2 print(len(c))
# ----> 3 plot=chan(c,visual=True)
#       4 plot.draw()
#
# TypeError: chan() got an unexpected keyword argument 'visual'

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chan   - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="chand"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#chan)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=chan(d,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Algorytm QuickHull
#
# <a id="quickhull"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Kod

# %% [markdown]
# <a id='section_id'></a>

# %%
def furthest(a, b, considering):
    n = len(considering)
    i = 0
    ans = None
    while i < n:
        if det(a, b, considering[i]) < 0:  # rozwazany wierzcholek jest po prawej stronie ab
            if ans == None or det(a, b, considering[i]) < det(a, b,
                                                              ans):  # |det(a,b,c)| = 1/2|ab|*h, gdzie h jest wysokoscia z c na ab
                ans = considering[i]
        i += 1
    return ans


def insideTriangle(a, b, c, i):
    if det(a, b, i) >= 0 and det(b, c, i) >= 0 and det(c, a, i) >= 0:
        return True
    return False


def removeInner(a, b, c, considering):
    new=[]
    for i in considering:
        if not insideTriangle(a, b, c, i):
            new.append(i)
    considering.clear()
    considering+=new

def quickHullUtil(a, b, considering,plot=None,hull=None):     
    if len(considering) == 0:
        return []
    
    if plot!=None :
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection(deepcopy(hull),color='green')],
                           lines=[LinesCollection([[a,b]],color='yellow')]))
        
    c = furthest(a, b, considering)
    if c == None:
        return []
    considering.remove(c)
    
    if plot!=None :
        hull.append(c)
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection(deepcopy(hull),color='green'),
                                    PointsCollection([c],color='red')],
                           lines=[LinesCollection([[a,b]],color='yellow')]))
    
    if plot!=None :
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection(deepcopy(hull),color='green')],
                           lines = [LinesCollection([[a,c],[b,c]],color='yellow')]))

    removeInner(a, c, b, considering)
    
    if plot!=None :
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection(deepcopy(hull),color='green')],
                           lines = [LinesCollection([[a,b],[a,c],[b,c]],color='yellow')]))
    
        z=quickHullUtil(a, c, considering,plot,hull)
        
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection(deepcopy(hull),color='green')],
                           lines = [LinesCollection([[b,c]],color='yellow')]))
        
        return z +[c]+ quickHullUtil(c, b, considering,plot,hull)
    
    return quickHullUtil(a, c, considering) +[c]+ quickHullUtil(c, b, considering)


def quickHull(points,visual=False):
    a = min(points, key=lambda x: x[0])
    b = max(points, key=lambda x: x[0])

    considering = deepcopy(points)
    
    if visual==True:
        plot=Plot(scenes=[Scene(points=[PointsCollection(deepcopy(considering))])])
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(considering)),
                                     PointsCollection([a,b],color='red')]))

    considering.remove(a)
    considering.remove(b)
    
    
    if visual:
        hull=[a,b]
        hoax =[a]+quickHullUtil(a, b, considering,plot,hull) +[b] + quickHullUtil(b, a, considering,plot,hull)
        plot.add_scene(Scene(points=[PointsCollection(deepcopy(points)),PointsCollection(deepcopy(hoax),color='green')],
                           lines=[LinesCollection(makeFullSheaf(hoax),color='yellow')]))
        return plot
    
    return [a]+quickHullUtil(a, b, considering)+[b]+  quickHullUtil(b, a, considering)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull - wizualizacja dla chmury punktów
#
# <a id="quickhulla"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull(a,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull - wizualizacja dla punktów o rozkładzie kołowym
#
# <a id="quickhullb"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull(b,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull  - wizualizacja dla punktów o rozkładzie prostokątnym
#
# <a id="quickhullc"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull(c,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### QuickHull  - wizualizacja dla punktów o rozkładzie na dwóh bokach, wierzchołkach i przekątnych prostokąta
#
# <a id="quickhulld"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)
#
# [Poczatek sekcji](#quickhull)

# %% [markdown]
# <a id='section_id'></a>

# %%
# %matplotlib notebook
plot=quickHull(d,visual=True)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Sekcja pomiarów czasu
#
# <a id="pomiary"></a>

# %% [markdown]
# ### Funkcja do pomiaru czasów i wizualizacji wyników

# %% [markdown]
# <a id='section_id'></a>

# %%
import time


from pure.graham import *
from pure.jarvis import *
from pure.divide_conq import *
from pure.chan import *
from pure.increase import *
from pure.lowerupper import *
from pure.quickhull import *

from lib.timemeasure import *

def generate_plot(xdatas, ydatas, xlabel, ylabel, title):
    for xdata, ydata in zip(xdatas, ydatas):
        plt.plot(xdata, ydata, ls = '--')
        plt.scatter(xdata, ydata)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Zredefiniowane kody funkcji funkcji wyznaczających otoczkę bez wizualizacji - wizualizacja mogła by wpływać na korzyść niektórych i niekorzyść innych. Przed uruchomieniem pomiarów czasu uruchomić komórki z nowymi definicjami.
#
# <a id="jarvis"></a>
# [spis treści](#spis)
#
# [Wybor zbiorow do wizualizcji](#ustalenieZbiorow)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ## Pomiary

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Chmura punktów

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 1000 + i * 100 for i in range(10) ]

funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_a = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeAset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_a[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_a[fi][i] = avg_exec_time(func, points=points.copy())
        
#         print(exectimes_a[fi][i])
        
    

    
pprint(exectimes_a)
# Out:
# <function graham at 0x7f4bd16ca040> 1000
# <function lower_upper at 0x7f4bcd0a5790> 1000
# <function chan at 0x7f4bcd0f5ee0> 1000
# <function quickHull at 0x7f4bcd0a5af0> 1000
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1000
# <function graham at 0x7f4bd16ca040> 1100
# <function lower_upper at 0x7f4bcd0a5790> 1100
# <function chan at 0x7f4bcd0f5ee0> 1100
# <function quickHull at 0x7f4bcd0a5af0> 1100
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1100
# <function graham at 0x7f4bd16ca040> 1200
# <function lower_upper at 0x7f4bcd0a5790> 1200
# <function chan at 0x7f4bcd0f5ee0> 1200
# <function quickHull at 0x7f4bcd0a5af0> 1200
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1200
# <function graham at 0x7f4bd16ca040> 1300
# <function lower_upper at 0x7f4bcd0a5790> 1300
# <function chan at 0x7f4bcd0f5ee0> 1300
# <function quickHull at 0x7f4bcd0a5af0> 1300
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1300
# <function graham at 0x7f4bd16ca040> 1400
# <function lower_upper at 0x7f4bcd0a5790> 1400
# <function chan at 0x7f4bcd0f5ee0> 1400
# <function quickHull at 0x7f4bcd0a5af0> 1400
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1400
# <function graham at 0x7f4bd16ca040> 1500
# <function lower_upper at 0x7f4bcd0a5790> 1500
# <function chan at 0x7f4bcd0f5ee0> 1500
# <function quickHull at 0x7f4bcd0a5af0> 1500
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1500
# <function graham at 0x7f4bd16ca040> 1600
# <function lower_upper at 0x7f4bcd0a5790> 1600
# <function chan at 0x7f4bcd0f5ee0> 1600
# <function quickHull at 0x7f4bcd0a5af0> 1600
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1600
# <function graham at 0x7f4bd16ca040> 1700
# <function lower_upper at 0x7f4bcd0a5790> 1700
# <function chan at 0x7f4bcd0f5ee0> 1700
# <function quickHull at 0x7f4bcd0a5af0> 1700
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1700
# <function graham at 0x7f4bd16ca040> 1800
# <function lower_upper at 0x7f4bcd0a5790> 1800
# <function chan at 0x7f4bcd0f5ee0> 1800
# <function quickHull at 0x7f4bcd0a5af0> 1800
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1800
# <function graham at 0x7f4bd16ca040> 1900
# <function lower_upper at 0x7f4bcd0a5790> 1900
# <function chan at 0x7f4bcd0f5ee0> 1900
# <function quickHull at 0x7f4bcd0a5af0> 1900
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1900
# array([[0.02261685, 0.02288044, 0.02636567, 0.0286531 , 0.02949847,
#         0.03310003, 0.03480884, 0.04267845, 0.04395959, 0.04647259],
#        [0.00577779, 0.00593294, 0.00639455, 0.00711049, 0.00775212,
#         0.0094531 , 0.00892511, 0.00970529, 0.00991227, 0.01097785],
#        [0.1516375 , 0.10203919, 0.21349828, 0.20731798, 0.12940227,
#         0.14271303, 0.25550836, 0.25411373, 0.29161511, 0.30232186],
#        [0.00266721, 0.00292603, 0.00322203, 0.00347985, 0.00382201,
#         0.00400323, 0.00544223, 0.00454474, 0.0049764 , 0.00542906],
#        [0.12611524, 0.15634199, 0.13686887, 0.11457464, 0.21755797,
#         0.147012  , 0.18974603, 0.21308633, 0.16009657, 0.20243993]])

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algorytm "górna-dolna"

# %%
# %matplotlib notebook


generate_plot([ns], [exectimes_a[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_a[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zbiorczy

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_a))], exectimes_a, 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull', 'Jarvis'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Rozkład kołowy

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 100 + i * 100 for i in range(10) ]
funcs = [graham, lower_upper, chan, quickHull, jarvis]

exectimes_b = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeBset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_b[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_b[fi][i] = avg_exec_time(func, points=points.copy())
        
    
pprint(exectimes_b)
# Out:
# <function graham at 0x7f4bd16ca040> 1000
# <function lower_upper at 0x7f4bcd0a5790> 1000
# <function chan at 0x7f4bcd0f5ee0> 1000
# <function quickHull at 0x7f4bcd0a5af0> 1000
# <function jarvis at 0x7f4bd1997790> zmieniam na np.array
# <function jarvis at 0x7f4bd1997790> 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-46b389a8935d> in <module>
#      19
#      20         print(func, n)
# ---> 21         exectimes_b[fi][i] = avg_exec_time(func, points=points.copy())
#      22
#      23
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in avg_exec_time(func, points, times, *args)
#      27     for _ in range(times):
#      28         points_copy = points.copy()
# ---> 29         total_exec_time += get_exec_time(func, *args, points = points_copy)
#      30
#      31     return total_exec_time / times
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in get_exec_time(func, points, *args)
#      14
#      15     tstart = timer()
# ---> 16     func(points, *args)
#      17     tstop = timer()
#      18     return (tstop - tstart)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/jarvis.py in jarvis(points)
#      34         for i in range(len(points)):
#      35             if i != prev and i != imax:
# ---> 36                 orient = orientation(points[prev], points[imax], points[i], EPS)
#      37                 # jeżeli punkt jest po prawej stronie rozważanego wektora,
#      38                 #to jest nowym kandydatem na punkt otoczki
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in orientation(p1, p2, p3, eps)
#      40     eps <- tolerancja dla zera
#      41     """
# ---> 42     det = det3x3(p1[0], p1[1], 1,
#      43                  p2[0], p2[1], 1,
#      44                  p3[0], p3[1], 1)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in det3x3(ux, uy, uz, vx, vy, vz, wx, wy, wz)
#      30             wx, wy, wz) -> float:
#      31     """ Zwraca wyznacznik 3x3 obliczony metodą Sarussa (bez redukcji wyrazów) """
# ---> 32     return (ux * vy * wz) + (uy * vz * wx) + (uz * vx * wy) - (wx * vy * uz) - (wy * vz * ux) - (wz * vx * uy)
#      33
#      34
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Algorytm Grahama

# %%
# %matplotlib notebook


generate_plot([ns], [exectimes_b[0]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Grahama')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algortym "górna-dolna"

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[1]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm "górna-dolna"')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algorytm Chana

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[2]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Chana')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algorytm QuickHull

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[3]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm QuickHull')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Algorytm Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns], [exectimes_b[4]], 'Liczba punktów', 'Czas wykonania [s]', 'Algorytm Jarvisa')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Ujęcie zbiorcze

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_b))], exectimes_b, 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull', 'Jarvis'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Ujęcie zbiorcze bez algorytmu Jarvisa

# %%
# %matplotlib notebook

generate_plot([ns for _ in range(len(exectimes_b) - 1)], exectimes_b[:len(exectimes_b)-1], 'Liczba punktów', 'Czas wykonania [s]', 'Ujęcie zbiorcze bez algorytmu Jarvisa')
plt.legend(labels=('graham', 'lowerupper', 'Chan', 'QuickHull'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Losowy rozkład na prostokącie

# %% [markdown]
# <a id='section_id'></a>

# %%
#lista liczb punktów na których ma być testowany algorytm 
ns = [ 1000 + i * 100 for i in range(10) ]
funcs = [graham, lower_upper, chan, jarvis]

exectimes_c = np.zeros(shape=(len(funcs), len(ns)))


for i, n in enumerate(ns):
    points = makeCset(n = n)
    for fi, func in enumerate(funcs):
        if func is jarvis:
            print(func, 'zmieniam na np.array')
            points = np.array(points)
        if func is increase_with_sorting: 
            continue
        if func is divide_conq:
            exectimes_c[fi][i] = avg_exec_time(func, 5, points=points)
            continue
        
        print(func, n)
        exectimes_c[fi][i] = avg_exec_time(func, points=points.copy())
        
    
pprint(exectimes_c)
# Out:
# <function graham at 0x7ff1b9c159d0> 1000
# <function lower_upper at 0x7ff1b9c21ee0> 1000
# <function chan at 0x7ff1b9c21700> 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-2e3314ffdbf4> in <module>
#      19
#      20         print(func, n)
# ---> 21         exectimes_c[fi][i] = avg_exec_time(func, points=points.copy())
#      22
#      23
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in avg_exec_time(func, points, times, *args)
#      27     for _ in range(times):
#      28         points_copy = points.copy()
# ---> 29         total_exec_time += get_exec_time(func, *args, points = points_copy)
#      30
#      31     return total_exec_time / times
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/timemeasure.py in get_exec_time(func, points, *args)
#      14
#      15     tstart = timer()
# ---> 16     func(points, *args)
#      17     tstop = timer()
#      18     return (tstop - tstart)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in chan(points)
#      50     hoax = None
#      51     while hoax == None:
# ---> 52         hoax = chanUtil(points, m)
#      53         m = min(n, m * m)
#      54
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in chanUtil(points, m)
#      37     while i < m:
#      38         ans.append(C[curr[0]][curr[1]])
# ---> 39         if nextvert(C, curr) == (0, 0):
#      40             return ans
#      41         curr = nextvert(C, curr)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/pure/chan.py in nextvert(C, curr)
#      19     nxt = (i, (j + 1) % len(C[i]))
#      20     for k in range(len(C)):
# ---> 21         t = tangent(C[i][j], C[k])
#      22         if t != None and k != i and compr(C[nxt[0]][nxt[1]], C[k][t], C[i][j]) > 0 and (k, t) != (curr):
#      23             nxt = (k, t)
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in tangent(p, Q, accur)
#     240
#     241
# --> 242     return tangetUtil(p, Q, 0, ln - 1)
#     243
#     244 def randomColor():
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in tangetUtil(p, Q, l, r)
#     232                     (Q[mid][1] <= p[1] <= Q[(mid + 1) % ln][1])):
#     233
# --> 234             while (det(p, Q[mid], Q[(mid + 1) % ln]) == 0):
#     235                 mid = (mid + 1) % ln  # jesli jest styczna wspolliniowa, to bierzmy pod uwage punkt blizszy
#     236             return mid
#
# ~/Documents/studies/cs/3_term/ageom/projekt/convexhull/lib/util.py in det(a, b, c)
#     203
#     204 def det(a,b,c):
# --> 205     return a[0]*b[1]-a[0]*c[1]-b[0]*a[1]+b[0]*c[1]+c[0]*a[1]-c[0]*b[1]
#     206
#     207 def tangent(p, Q, accur=0):  # Q-zbior punktow w formie otoczki
#
# KeyboardInterrupt:

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# ### Wierzchołki kwadratu, jego przekątne i dwa boki o wspólnym wierzchołku

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <a id='section_id'></a>
